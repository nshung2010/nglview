# %%
import pytraj
import nglview as nv

traj = pytraj.datafiles.load_trpcage()
print(traj)
view = nv.show_pytraj(traj, default=False)
view.center()
view.add_licorice(color='grey')
view.add_surface(color='residueindex', opacity=0.5)
view
# Out:
# _ColormakerRegistry()
# pytraj.TrajectoryIterator, 38 frames:
# Size: 0.000258 (GB)
# <Topology: 304 atoms, 20 residues, 1 mols, non-PBC>
# NGLWidget(max_frame=37)

# %%
from nglview.contrib.movie import MovieMaker

maker = MovieMaker(view, in_memory=True,
                   render_params={'factor': 10})
maker.output = './test.gif'
maker.make()
# Out:
# IntProgress(value=0, description='Rendering ...', max=37)

# %%
from IPython.display import Image

# %%
Image("./test.gif")
